# %% [markdown]
# # Implementation of the RBLP algorithm

# %%
from help_functions import SynthetizeSignalStrube, LSQ, DUTTER, WLSQ, CalculateCoefficients, SynthetizeSignalDirac
import numpy as np
import math
from scipy import signal
import matplotlib.pyplot as plt

# %% [markdown]
# # Sythetize excitation signals
# 1. Strube's glottal wave excitation (without noise)
# 2. Strube's glottal wave excitation (with noise)
# 3. Train of Dirac pulses excitation (without noise)
# 4. Train of Dirac pulses excitation (with noise)

# %%
# AR model parameters
A = [1, -2.22, 2.89, -3.08, 3.27, -2.77, 2.35, -1.7, 0.75]
f_pitch = 125
# Synthetize signal with Strube's glottal wave excitation
s_strube_orig, s_strube = SynthetizeSignalStrube(A)
# Synthetize signal with train of Dirac pulses excitation
s_dirac_orig, s_dirac = SynthetizeSignalDirac(A)

# %% [markdown]
# # Calculate coefficients in the case of Strube's glottal wave excitation
# Case without noise

# %%
A_LSQ1, A_DUTTER1, A_WLSQ1 = CalculateCoefficients(s_strube_orig)
plt.plot( A_LSQ1[:,0], 'b' )
plt.plot( A_DUTTER1[:,0], 'r' )
plt.plot( A_WLSQ1[:,0], 'k' )
plt.title('$Parameter \ a_{1}$')
plt.xlabel('samples')
plt.show()

# %% [markdown]
# Case with noise

# %%
A_LSQ2, A_DUTTER2, A_WLSQ2 = CalculateCoefficients(s_strube)
plt.plot( A_LSQ2[:,0], 'b' )
plt.plot( A_DUTTER2[:,0], 'r' )
plt.plot( A_WLSQ2[:,0], 'k' )
plt.title('$Parameter \ a_{1}$')
plt.xlabel('samples')
plt.show()

# %% [markdown]
# #  Calculate coefficients in the case of Train of Dirac pulese excitation
# Case without noise

# %%
A_LSQ3, A_DUTTER3, A_WLSQ3 = CalculateCoefficients(s_dirac_orig)
plt.plot( A_LSQ3[:,0], 'b' )
plt.plot( A_DUTTER3[:,0], 'r' )
plt.plot( A_WLSQ3[:,0], 'k' )
plt.title('$Parameter \ a_{1}$')
plt.xlabel('samples')
plt.show()

# %% [markdown]
# Case with noise

# %%
A_LSQ4, A_DUTTER4, A_WLSQ4 = CalculateCoefficients(s_dirac)
plt.plot( A_LSQ4[:,0], 'b' )
plt.plot( A_DUTTER4[:,0], 'r' )
plt.plot( A_WLSQ4[:,0], 'k' )
plt.title('$Parameter \ a_{1}$')
plt.xlabel('samples')
plt.show()
